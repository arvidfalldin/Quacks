# %%
from game_mechanics.bag import Bag
from game_mechanics.chips import Chip, ChipColor, STARTING_CHIPS

my_bag = Bag()
my_bag.add(STARTING_CHIPS)

chip = my_bag.draw()
print(chip)
my_bag.add(chip)
# Out:
# o1
